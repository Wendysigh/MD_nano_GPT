# %%
import pyemma
import mdshare
import numpy as np

# %%
file = mdshare.fetch('alanine-dipeptide-3x250ns-backbone-dihedrals.npz', working_directory='data')

# %%
with np.load(file) as fh:
    trajs = [fh[key] for key in sorted(fh.keys())]

# %%
trajs[0].shape
# Out:
# (250000, 2)

# %%
file = mdshare.fetch('hmm-doublewell-2d-100k.npz', working_directory='data')

# %%
datapath = f'/home/wzengad/projects/MD_code/data/RMSD/train'
input_x = np.loadtxt(datapath, dtype=int).reshape(-1)

# %%
input_x = input_x[:1000]

# %%
import pandas as pd
df=pd.DataFrame(input_x)

# %%
df.groupby(df[0].ne(df[0].shift()).cumsum())[0].transform('size')
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 995    5
# 996    5
# 997    5
# 998    5
# 999    5
# Name: 0, Length: 1000, dtype: int64
